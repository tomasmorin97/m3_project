# %% [markdown]
# # Machine Learning: Modelo supervisado de regresión

# %%
# Importar librerías

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Lectura de datos

# %%
diamonds_train = pd.read_csv('./data/diamonds_train.csv')
diamonds_train.head()
# Out:
#    price  carat  depth  table     x     y     z        cut color clarity  \
# 0   4268   1.21   62.4   58.0  6.83  6.79  4.25    Premium     J     VS2
# 1    505   0.32   63.0   57.0  4.35  4.38  2.75  Very Good     H     VS2
# 2   2686   0.71   65.5   55.0  5.62  5.53  3.65       Fair     G     VS1
# 3    738   0.41   63.8   56.0  4.68  4.72  3.00       Good     D     SI1
# 4   4882   1.02   60.5   59.0  6.55  6.51  3.95      Ideal     G     SI1
#
#         city
# 0      Dubai
# 1   Kimberly
# 2  Las Vegas
# 3   Kimberly
# 4      Dubai

# %%
columnas_reordenadas = ['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x', 'y', 'z', 'city', 'price']
diamonds_train = diamonds_train[columnas_reordenadas]
diamonds_train
# Out:
#        carat        cut color clarity  depth  table     x     y     z  \
# 0       1.21    Premium     J     VS2   62.4   58.0  6.83  6.79  4.25
# 1       0.32  Very Good     H     VS2   63.0   57.0  4.35  4.38  2.75
# 2       0.71       Fair     G     VS1   65.5   55.0  5.62  5.53  3.65
# 3       0.41       Good     D     SI1   63.8   56.0  4.68  4.72  3.00
# 4       1.02      Ideal     G     SI1   60.5   59.0  6.55  6.51  3.95
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...
# 40450   1.34      Ideal     G     VS1   62.7   57.0  7.10  7.04  4.43
# 40451   2.02       Good     F     SI2   57.1   60.0  8.31  8.25  4.73
# 40452   1.01      Ideal     H     SI1   62.7   56.0  6.37  6.42  4.01
# 40453   0.33      Ideal     J     VS1   61.9   54.3  4.45  4.47  2.76
# 40454   1.24      Ideal     I     SI1   62.0   58.0  6.83  6.88  4.25
#
#             city  price
# 0          Dubai   4268
# 1       Kimberly    505
# 2      Las Vegas   2686
# 3       Kimberly    738
# 4          Dubai   4882
# ...          ...    ...
# 40450    Antwerp  10070
# 40451     Madrid  12615
# 40452   Kimberly   5457
# 40453   Kimberly    456
# 40454     London   6232
#
# [40455 rows x 11 columns]

# %% [markdown]
# ## Análisis exploratorio

# %% [markdown]
# ### General

# %%
diamonds_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40455 entries, 0 to 40454
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    40455 non-null  float64
#  1   cut      40455 non-null  object
#  2   color    40455 non-null  object
#  3   clarity  40455 non-null  object
#  4   depth    40455 non-null  float64
#  5   table    40455 non-null  float64
#  6   x        40455 non-null  float64
#  7   y        40455 non-null  float64
#  8   z        40455 non-null  float64
#  9   city     40455 non-null  object
#  10  price    40455 non-null  int64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 3.4+ MB

# %%
def cat_var(df, cols):
    '''
    Return: a Pandas dataframe object with the following columns:
        - "categorical_variable" => every categorical variable include as an input parameter (string).
        - "number_of_possible_values" => the amount of unique values that can take a given categorical variable (integer).
        - "values" => a list with the posible unique values for every categorical variable (list).

    Input parameters:
        - df -> Pandas dataframe object: a dataframe with categorical variables.
        - cols -> list object: a list with the name (string) of every categorical variable to analyse.
    '''
    cat_list = []
    for col in cols:
        cat = df[col].unique()
        cat_num = len(cat)
        cat_dict = {"categorical_variable":col,
                    "number_of_possible_values":cat_num,
                    "values":cat}
        cat_list.append(cat_dict)
    df = pd.DataFrame(cat_list).sort_values(by="number_of_possible_values", ascending=False)
    return df.reset_index(drop=True)

# %%
col_diamonds_train = list(diamonds_train.columns)
cat_diamonds_train = cat_var(diamonds_train, col_diamonds_train)
cat_diamonds_train
# Out:
#    categorical_variable  number_of_possible_values  \
# 0                 price                      10378
# 1                     x                        543
# 2                     y                        539
# 3                     z                        363
# 4                 carat                        270
# 5                 depth                        175
# 6                 table                        121
# 7                  city                         13
# 8               clarity                          8
# 9                 color                          7
# 10                  cut                          5
#
#                                                values
# 0   [4268, 505, 2686, 738, 4882, 9057, 3733, 8608,...
# 1   [6.83, 4.35, 5.62, 4.68, 6.55, 7.45, 6.23, 7.3...
# 2   [6.79, 4.38, 5.53, 4.72, 6.51, 7.39, 6.19, 7.3...
# 3   [4.25, 2.75, 3.65, 3.0, 3.95, 4.54, 4.05, 4.57...
# 4   [1.21, 0.32, 0.71, 0.41, 1.02, 1.52, 1.01, 0.3...
# 5   [62.4, 63.0, 65.5, 63.8, 60.5, 61.2, 65.2, 62....
# 6   [58.0, 57.0, 55.0, 56.0, 59.0, 54.2, 63.0, 61....
# 7   [Dubai, Kimberly, Las Vegas, Tel Aviv, Amsterd...
# 8            [VS2, VS1, SI1, SI2, IF, VVS1, VVS2, I1]
# 9                               [J, H, G, D, F, E, I]
# 10            [Premium, Very Good, Fair, Good, Ideal]

# %%
diamonds_train.eq(0).sum()
# Out:
# carat       0
# cut         0
# color       0
# clarity     0
# depth       0
# table       0
# x           5
# y           4
# z          16
# city        0
# price       0
# dtype: int64

# %%
diamonds_train = diamonds_train[(diamonds_train != 0).all(axis=1)]

# %%
diamonds_train.eq(0).sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# city       0
# price      0
# dtype: int64

# %%
# Crear un gráfico de dispersión
plt.figure(figsize=(8, 6))
plt.scatter(diamonds_train['carat'], diamonds_train['price'], alpha=1, color='blue')

# Personalizar el gráfico
plt.title('Gráfico de Dispersión entre Carat y Price')
plt.xlabel('Carat')
plt.ylabel('Price')
plt.grid(True)

# Mostrar el gráfico
plt.show()

# %%
# Crear un histplot
sns.histplot(data=diamonds_train, x='carat', bins=20, kde=False, color='blue', edgecolor='black')

# Personalizar el gráfico
plt.title('Histplot de la Variable Numérica')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')

# Mostrar el gráfico
plt.show()
# Out:
# [CV 3/5] END min_samples_leaf=1, min_samples_split=8, n_estimators=300;, score=-542.046 total time= 1.1min
# [CV 3/5] END min_samples_leaf=1, min_samples_split=8, n_estimators=400;, score=-540.968 total time= 1.4min
# [CV 2/5] END min_samples_leaf=1, min_samples_split=8, n_estimators=500;, score=-536.715 total time= 1.8min
# [CV 1/5] END min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=-536.617 total time= 1.3min
# [CV 2/5] END min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=-536.965 total time= 1.1min
# [CV 1/5] END min_samples_leaf=1, min_samples_split=10, n_estimators=400;, score=-536.301 total time= 1.9min
# [CV 5/5] END min_samples_leaf=1, min_samples_split=10, n_estimators=400;, score=-534.395 total time= 1.4min
# [CV 4/5] END min_samples_leaf=1, min_samples_split=10, n_estimators=500;, score=-571.003 total time= 1.7min
# [CV 4/5] END min_samples_leaf=1, min_samples_split=15, n_estimators=300;, score=-577.025 total time=  55.5s
# [CV 3/5] END min_samples_leaf=1, min_samples_split=15, n_estimators=400;, score=-544.785 total time= 1.4min
# [CV 2/5] END min_samples_leaf=1, min_samples_split=15, n_estimators=500;, score=-539.143 total time= 1.8min
# [CV 1/5] END min_samples_leaf=2, min_samples_split=8, n_estimators=300;, score=-535.382 total time= 1.3min
# [CV 4/5] END min_samples_leaf=2, min_samples_split=8, n_estimators=300;, score=-570.759 total time= 1.2min
# [CV 3/5] END min_samples_leaf=2, min_samples_split=8, n_estimators=400;, score=-541.915 total time= 1.5min
# [CV 2/5] END min_samples_leaf=2, min_samples_split=8, n_estimators=500;, score=-535.581 total time= 1.7min
# [CV 1/5] END min_samples_leaf=2, min_samples_split=10, n_estimators=300;, score=-535.891 total time= 1.1min
# [CV 4/5] END min_samples_leaf=2, min_samples_split=10, n_estimators=300;, score=-572.449 total time=  56.6s
# [CV 3/5] END min_samples_leaf=2, min_samples_split=10, n_estimators=400;, score=-542.677 total time= 1.3min
# [CV 2/5] END min_samples_leaf=2, min_samples_split=10, n_estimators=500;, score=-535.671 total time= 1.5min
# [CV 1/5] END min_samples_leaf=2, min_samples_split=15, n_estimators=300;, score=-538.939 total time=  49.8s
# [CV 4/5] END min_samples_leaf=2, min_samples_split=15, n_estimators=300;, score=-577.586 total time=  55.5s
# [CV 3/5] END min_samples_leaf=2, min_samples_split=15, n_estimators=400;, score=-546.004 total time= 1.1min
# [CV 2/5] END min_samples_leaf=2, min_samples_split=15, n_estimators=500;, score=-538.107 total time= 1.4min
# [CV 1/5] END min_samples_leaf=3, min_samples_split=8, n_estimators=300;, score=-535.881 total time=  55.2s
# [CV 4/5] END min_samples_leaf=3, min_samples_split=8, n_estimators=300;, score=-572.322 total time=  53.6s
# [CV 3/5] END min_samples_leaf=3, min_samples_split=8, n_estimators=400;, score=-544.650 total time= 1.4min
# [CV 2/5] END min_samples_leaf=3, min_samples_split=8, n_estimators=500;, score=-536.853 total time= 1.7min
# [CV 1/5] END min_samples_leaf=3, min_samples_split=10, n_estimators=300;, score=-536.468 total time=  59.8s
# [CV 4/5] END min_samples_leaf=3, min_samples_split=10, n_estimators=300;, score=-574.004 total time=  57.8s
# [CV 3/5] END min_samples_leaf=3, min_samples_split=10, n_estimators=400;, score=-545.873 total time= 1.3min
# [CV 2/5] END min_samples_leaf=3, min_samples_split=10, n_estimators=500;, score=-536.998 total time= 1.5min
# [CV 1/5] END min_samples_leaf=3, min_samples_split=15, n_estimators=300;, score=-539.510 total time=  48.4s
# [CV 4/5] END min_samples_leaf=3, min_samples_split=15, n_estimators=300;, score=-578.690 total time=  49.2s
# [CV 2/5] END min_samples_leaf=3, min_samples_split=15, n_estimators=400;, score=-539.626 total time= 1.1min
# [CV 1/5] END min_samples_leaf=3, min_samples_split=15, n_estimators=500;, score=-539.163 total time= 1.4min
# [CV 2/5] END min_samples_leaf=1, min_samples_split=8, n_estimators=300;, score=-536.711 total time= 1.1min
# [CV 1/5] END min_samples_leaf=1, min_samples_split=8, n_estimators=400;, score=-535.418 total time= 1.4min
# [CV 1/5] END min_samples_leaf=1, min_samples_split=8, n_estimators=500;, score=-535.245 total time= 1.8min
# [CV 5/5] END min_samples_leaf=1, min_samples_split=8, n_estimators=500;, score=-533.506 total time= 2.1min
# [CV 5/5] END min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=-534.753 total time= 1.3min
# [CV 4/5] END min_samples_leaf=1, min_samples_split=10, n_estimators=400;, score=-570.933 total time= 1.7min
# [CV 3/5] END min_samples_leaf=1, min_samples_split=10, n_estimators=500;, score=-541.171 total time= 1.8min
# [CV 2/5] END min_samples_leaf=1, min_samples_split=15, n_estimators=300;, score=-539.202 total time=  51.9s
# [CV 5/5] END min_samples_leaf=1, min_samples_split=15, n_estimators=300;, score=-536.115 total time=  58.7s
# [CV 4/5] END min_samples_leaf=1, min_samples_split=15, n_estimators=400;, score=-576.410 total time= 1.5min
# [CV 3/5] END min_samples_leaf=1, min_samples_split=15, n_estimators=500;, score=-544.632 total time= 1.9min
# [CV 2/5] END min_samples_leaf=2, min_samples_split=8, n_estimators=300;, score=-535.571 total time= 1.2min
# [CV 5/5] END min_samples_leaf=2, min_samples_split=8, n_estimators=300;, score=-533.975 total time= 1.2min
# [CV 4/5] END min_samples_leaf=2, min_samples_split=8, n_estimators=400;, score=-569.816 total time= 1.4min
# [CV 3/5] END min_samples_leaf=2, min_samples_split=8, n_estimators=500;, score=-542.003 total time= 1.7min
# [CV 2/5] END min_samples_leaf=2, min_samples_split=10, n_estimators=300;, score=-535.821 total time= 1.1min
# [CV 5/5] END min_samples_leaf=2, min_samples_split=10, n_estimators=300;, score=-534.180 total time=  58.9s
# [CV 4/5] END min_samples_leaf=2, min_samples_split=10, n_estimators=400;, score=-571.497 total time= 1.2min
# [CV 3/5] END min_samples_leaf=2, min_samples_split=10, n_estimators=500;, score=-542.886 total time= 1.5min
# [CV 2/5] END min_samples_leaf=2, min_samples_split=15, n_estimators=300;, score=-538.249 total time=  50.5s
# [CV 5/5] END min_samples_leaf=2, min_samples_split=15, n_estimators=300;, score=-536.109 total time=  56.0s
# [CV 4/5] END min_samples_leaf=2, min_samples_split=15, n_estimators=400;, score=-576.712 total time= 1.1min
# [CV 3/5] END min_samples_leaf=2, min_samples_split=15, n_estimators=500;, score=-546.074 total time= 1.4min
# [CV 2/5] END min_samples_leaf=3, min_samples_split=8, n_estimators=300;, score=-537.708 total time=  54.5s
# [CV 5/5] END min_samples_leaf=3, min_samples_split=8, n_estimators=300;, score=-533.641 total time=  54.0s
# [CV 4/5] END min_samples_leaf=3, min_samples_split=8, n_estimators=400;, score=-571.316 total time= 1.4min
# [CV 3/5] END min_samples_leaf=3, min_samples_split=8, n_estimators=500;, score=-544.640 total time= 1.7min
# [CV 2/5] END min_samples_leaf=3, min_samples_split=10, n_estimators=300;, score=-537.746 total time=  58.7s
# [CV 5/5] END min_samples_leaf=3, min_samples_split=10, n_estimators=300;, score=-533.670 total time=  57.4s
# [CV 4/5] END min_samples_leaf=3, min_samples_split=10, n_estimators=400;, score=-573.032 total time= 1.3min
# [CV 3/5] END min_samples_leaf=3, min_samples_split=10, n_estimators=500;, score=-545.770 total time= 1.5min
# [CV 2/5] END min_samples_leaf=3, min_samples_split=15, n_estimators=300;, score=-539.724 total time=  48.5s
# [CV 5/5] END min_samples_leaf=3, min_samples_split=15, n_estimators=300;, score=-536.140 total time=  49.0s
# [CV 4/5] END min_samples_leaf=3, min_samples_split=15, n_estimators=400;, score=-577.824 total time= 1.1min
# [CV 3/5] END min_samples_leaf=3, min_samples_split=15, n_estimators=500;, score=-548.339 total time= 1.3min
# [CV 1/5] END min_samples_leaf=1, min_samples_split=8, n_estimators=300;, score=-535.745 total time= 1.1min
# [CV 5/5] END min_samples_leaf=1, min_samples_split=8, n_estimators=300;, score=-534.496 total time= 1.0min
# [CV 4/5] END min_samples_leaf=1, min_samples_split=8, n_estimators=400;, score=-569.081 total time= 1.5min
# [CV 3/5] END min_samples_leaf=1, min_samples_split=8, n_estimators=500;, score=-540.964 total time= 2.1min
# [CV 3/5] END min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=-541.923 total time= 1.1min
# [CV 2/5] END min_samples_leaf=1, min_samples_split=10, n_estimators=400;, score=-536.843 total time= 1.9min
# [CV 1/5] END min_samples_leaf=1, min_samples_split=10, n_estimators=500;, score=-536.261 total time= 1.7min
# [CV 5/5] END min_samples_leaf=1, min_samples_split=10, n_estimators=500;, score=-533.707 total time= 1.7min
# [CV 1/5] END min_samples_leaf=1, min_samples_split=15, n_estimators=400;, score=-538.860 total time= 1.3min
# [CV 5/5] END min_samples_leaf=1, min_samples_split=15, n_estimators=400;, score=-535.984 total time= 1.5min
# [CV 4/5] END min_samples_leaf=1, min_samples_split=15, n_estimators=500;, score=-576.643 total time= 2.0min
# [CV 3/5] END min_samples_leaf=2, min_samples_split=8, n_estimators=300;, score=-542.652 total time= 1.2min
# [CV 2/5] END min_samples_leaf=2, min_samples_split=8, n_estimators=400;, score=-535.585 total time= 1.5min
# [CV 1/5] END min_samples_leaf=2, min_samples_split=8, n_estimators=500;, score=-534.982 total time= 1.7min
# [CV 5/5] END min_samples_leaf=2, min_samples_split=8, n_estimators=500;, score=-533.310 total time= 1.8min
# [CV 1/5] END min_samples_leaf=2, min_samples_split=10, n_estimators=400;, score=-535.858 total time= 1.3min
# [CV 5/5] END min_samples_leaf=2, min_samples_split=10, n_estimators=400;, score=-533.933 total time= 1.2min
# [CV 4/5] END min_samples_leaf=2, min_samples_split=10, n_estimators=500;, score=-571.770 total time= 1.5min
# [CV 3/5] END min_samples_leaf=2, min_samples_split=15, n_estimators=300;, score=-546.789 total time=  53.8s
# [CV 2/5] END min_samples_leaf=2, min_samples_split=15, n_estimators=400;, score=-538.390 total time= 1.2min
# [CV 1/5] END min_samples_leaf=2, min_samples_split=15, n_estimators=500;, score=-538.639 total time= 1.4min
# [CV 5/5] END min_samples_leaf=2, min_samples_split=15, n_estimators=500;, score=-535.412 total time= 1.4min
# [CV 1/5] END min_samples_leaf=3, min_samples_split=8, n_estimators=400;, score=-535.816 total time= 1.2min
# [CV 5/5] END min_samples_leaf=3, min_samples_split=8, n_estimators=400;, score=-533.725 total time= 1.4min
# [CV 4/5] END min_samples_leaf=3, min_samples_split=8, n_estimators=500;, score=-571.568 total time= 1.7min
# [CV 3/5] END min_samples_leaf=3, min_samples_split=10, n_estimators=300;, score=-546.193 total time=  57.2s
# [CV 2/5] END min_samples_leaf=3, min_samples_split=10, n_estimators=400;, score=-537.467 total time= 1.3min
# [CV 1/5] END min_samples_leaf=3, min_samples_split=10, n_estimators=500;, score=-536.161 total time= 1.6min
# [CV 5/5] END min_samples_leaf=3, min_samples_split=10, n_estimators=500;, score=-533.347 total time= 1.4min
# [CV 1/5] END min_samples_leaf=3, min_samples_split=15, n_estimators=400;, score=-539.434 total time= 1.1min
# [CV 5/5] END min_samples_leaf=3, min_samples_split=15, n_estimators=400;, score=-536.115 total time= 1.1min
# [CV 4/5] END min_samples_leaf=3, min_samples_split=15, n_estimators=500;, score=-577.985 total time= 1.2min
# [CV 4/5] END min_samples_leaf=1, min_samples_split=8, n_estimators=300;, score=-570.091 total time= 1.1min
# [CV 2/5] END min_samples_leaf=1, min_samples_split=8, n_estimators=400;, score=-536.654 total time= 1.4min
# [CV 5/5] END min_samples_leaf=1, min_samples_split=8, n_estimators=400;, score=-534.245 total time= 1.5min
# [CV 4/5] END min_samples_leaf=1, min_samples_split=8, n_estimators=500;, score=-568.981 total time= 2.1min
# [CV 4/5] END min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=-571.826 total time= 1.1min
# [CV 3/5] END min_samples_leaf=1, min_samples_split=10, n_estimators=400;, score=-540.964 total time= 1.9min
# [CV 2/5] END min_samples_leaf=1, min_samples_split=10, n_estimators=500;, score=-536.728 total time= 1.7min
# [CV 1/5] END min_samples_leaf=1, min_samples_split=15, n_estimators=300;, score=-538.938 total time=  56.2s
# [CV 3/5] END min_samples_leaf=1, min_samples_split=15, n_estimators=300;, score=-545.466 total time=  54.5s
# [CV 2/5] END min_samples_leaf=1, min_samples_split=15, n_estimators=400;, score=-539.230 total time= 1.4min
# [CV 1/5] END min_samples_leaf=1, min_samples_split=15, n_estimators=500;, score=-538.666 total time= 1.8min
# [CV 5/5] END min_samples_leaf=1, min_samples_split=15, n_estimators=500;, score=-535.560 total time= 2.0min
# [CV 1/5] END min_samples_leaf=2, min_samples_split=8, n_estimators=400;, score=-535.084 total time= 1.6min
# [CV 5/5] END min_samples_leaf=2, min_samples_split=8, n_estimators=400;, score=-533.977 total time= 1.3min
# [CV 4/5] END min_samples_leaf=2, min_samples_split=8, n_estimators=500;, score=-569.934 total time= 1.8min
# [CV 3/5] END min_samples_leaf=2, min_samples_split=10, n_estimators=300;, score=-543.472 total time=  56.0s
# [CV 2/5] END min_samples_leaf=2, min_samples_split=10, n_estimators=400;, score=-535.912 total time= 1.3min
# [CV 1/5] END min_samples_leaf=2, min_samples_split=10, n_estimators=500;, score=-535.835 total time= 1.5min
# [CV 5/5] END min_samples_leaf=2, min_samples_split=10, n_estimators=500;, score=-533.322 total time= 1.5min
# [CV 1/5] END min_samples_leaf=2, min_samples_split=15, n_estimators=400;, score=-538.909 total time= 1.2min
# [CV 5/5] END min_samples_leaf=2, min_samples_split=15, n_estimators=400;, score=-535.972 total time= 1.1min
# [CV 4/5] END min_samples_leaf=2, min_samples_split=15, n_estimators=500;, score=-576.926 total time= 1.4min
# [CV 3/5] END min_samples_leaf=3, min_samples_split=8, n_estimators=300;, score=-545.275 total time=  53.7s
# [CV 2/5] END min_samples_leaf=3, min_samples_split=8, n_estimators=400;, score=-537.282 total time= 1.3min
# [CV 1/5] END min_samples_leaf=3, min_samples_split=8, n_estimators=500;, score=-535.524 total time= 1.7min
# [CV 5/5] END min_samples_leaf=3, min_samples_split=8, n_estimators=500;, score=-533.168 total time= 1.7min
# [CV 1/5] END min_samples_leaf=3, min_samples_split=10, n_estimators=400;, score=-536.395 total time= 1.3min
# [CV 5/5] END min_samples_leaf=3, min_samples_split=10, n_estimators=400;, score=-533.800 total time= 1.3min
# [CV 4/5] END min_samples_leaf=3, min_samples_split=10, n_estimators=500;, score=-573.291 total time= 1.4min
# [CV 3/5] END min_samples_leaf=3, min_samples_split=15, n_estimators=300;, score=-548.756 total time=  49.6s
# [CV 3/5] END min_samples_leaf=3, min_samples_split=15, n_estimators=400;, score=-548.406 total time= 1.1min
# [CV 2/5] END min_samples_leaf=3, min_samples_split=15, n_estimators=500;, score=-539.176 total time= 1.4min
# [CV 5/5] END min_samples_leaf=3, min_samples_split=15, n_estimators=500;, score=-535.770 total time=  55.7s

# %% [markdown]
# ### Variables categóricas

# %%
diamonds_train['cut'].value_counts()
# Habría que darles una ordinalidad de mejor a peor: Premium, Ideal, Very Good, Good, Fair (5-1)
# Out:
# cut
# Ideal        16218
# Premium      10251
# Very Good     9095
# Good          3659
# Fair          1216
# Name: count, dtype: int64

# %%
diamonds_train['clarity'].value_counts()
# Se podrían agrupar por tipo de claridad
# Out:
# clarity
# SI1     9747
# VS2     9246
# SI2     6920
# VS1     6065
# VVS2    3799
# VVS1    2774
# IF      1327
# I1       561
# Name: count, dtype: int64

# %%
diamonds_train['city'].value_counts()
# Se podría agrupar por continente
# Out:
# city
# Surat            5071
# Antwerp          5046
# Kimberly         4972
# Luxembourg       2606
# Las Vegas        2586
# New York City    2584
# Dubai            2560
# Madrid           2537
# Paris            2529
# Tel Aviv         2504
# Zurich           2497
# Amsterdam        2485
# London           2462
# Name: count, dtype: int64

# %%
diamonds_train['color'].value_counts()
# Out:
# color
# G    8449
# E    7325
# F    7173
# H    6272
# D    5049
# I    4031
# J    2140
# Name: count, dtype: int64

# %%
sns.countplot(x='color', data=diamonds_train)
plt.show()

# %%
diamonds_train.groupby('color')['price'].mean()
# Out:
# color
# D    3134.943157
# E    3088.342526
# F    3677.586923
# G    4021.065215
# H    4468.987883
# I    5088.312081
# J    5346.234112
# Name: price, dtype: float64

# %% [markdown]
# ### Variables numéricas

# %%
diamonds_train.describe()
# Out:
#               carat         depth         table             x             y  \
# count  40439.000000  40439.000000  40439.000000  40439.000000  40439.000000
# mean       0.797425     61.753013     57.445543      5.729616      5.732897
# std        0.475257      1.431306      2.233055      1.122384      1.145002
# min        0.200000     43.000000     43.000000      3.770000      3.720000
# 25%        0.400000     61.000000     56.000000      4.710000      4.720000
# 50%        0.700000     61.800000     57.000000      5.690000      5.710000
# 75%        1.040000     62.500000     59.000000      6.540000      6.540000
# max        4.500000     79.000000     95.000000     10.230000     58.900000
#
#                   z         price
# count  40439.000000  40439.000000
# mean       3.538553   3926.535448
# std        0.693639   3990.024501
# min        1.070000    326.000000
# 25%        2.910000    945.000000
# 50%        3.520000   2396.000000
# 75%        4.040000   5329.500000
# max        8.060000  18823.000000

# %%
diamonds_train_num = diamonds_train.select_dtypes(include=['number'])
diamonds_train_num
# Out:
#        carat  depth  table     x     y     z  price
# 0       1.21   62.4   58.0  6.83  6.79  4.25   4268
# 1       0.32   63.0   57.0  4.35  4.38  2.75    505
# 2       0.71   65.5   55.0  5.62  5.53  3.65   2686
# 3       0.41   63.8   56.0  4.68  4.72  3.00    738
# 4       1.02   60.5   59.0  6.55  6.51  3.95   4882
# ...      ...    ...    ...   ...   ...   ...    ...
# 40450   1.34   62.7   57.0  7.10  7.04  4.43  10070
# 40451   2.02   57.1   60.0  8.31  8.25  4.73  12615
# 40452   1.01   62.7   56.0  6.37  6.42  4.01   5457
# 40453   0.33   61.9   54.3  4.45  4.47  2.76    456
# 40454   1.24   62.0   58.0  6.83  6.88  4.25   6232
#
# [40439 rows x 7 columns]

# %%
# Configurar el tamaño de la figura
plt.figure(figsize=(3, 5))

# Crear un boxplot para la variable "price"
sns.boxplot(y=diamonds_train['price'])

# Añadir etiquetas y título
plt.xlabel('Price')
plt.title('Boxplot de la Variable "Price"')

# Mostrar el gráfico
plt.show()

# %%
# Configurar el tamaño de la figura
plt.figure(figsize=(3, 5))

# Crear un boxplot para la variable "price"
sns.boxplot(y=y_pred_df['price'])

# Añadir etiquetas y título
plt.xlabel('Price')
plt.title('Boxplot de la Variable "Price"')

# Mostrar el gráfico
plt.show()

# %%
# Configurar el tamaño de la figura
plt.figure(figsize=(3, 5))

# Crear un boxplot para la variable "price"
sns.boxplot(y=diamonds_train['depth'])

# Añadir etiquetas y título
plt.xlabel('depth')
plt.title('Boxplot de la Variable "depth"')

# Mostrar el gráfico
plt.show()

# %%
# Calcular el rango intercuartílico (IQR)
#Q1 = diamonds_train['depth'].quantile(0.25)
#Q3 = diamonds_train['depth'].quantile(0.75)
#IQR = Q3 - Q1

# Definir límites para identificar outliers
#limite_inferior = Q1 - 1.5 * IQR
#limite_superior = Q3 + 1.5 * IQR

# Filtrar los datos para eliminar outliers
#diamonds_train = diamonds_train[(diamonds_train['depth'] >= limite_inferior) & (diamonds_train['depth'] <= limite_superior)]

# Visualizar el DataFrame resultante sin outliers
######diamonds_train

# %%
# Configurar el tamaño de la figura
plt.figure(figsize=(3, 5))

# Crear un boxplot para la variable "price"
sns.boxplot(y=diamonds_train['table'])

# Añadir etiquetas y título
plt.xlabel('table')
plt.title('Boxplot de la Variable "table"')

# Mostrar el gráfico
plt.show()

# %%
# Calcular el rango intercuartílico (IQR)
#Q1 = diamonds_train['table'].quantile(0.25)
#Q3 = diamonds_train['table'].quantile(0.75)
#IQR = Q3 - Q1

# Definir límites para identificar outliers
#limite_inferior = Q1 - 1.75 * IQR
#limite_superior = Q3 + 1.75 * IQR

# Filtrar los datos para eliminar outliers
#diamonds_train = diamonds_train[(diamonds_train['table'] >= limite_inferior) & (diamonds_train['table'] <= limite_superior)]

# Visualizar el DataFrame resultante sin outliers
#diamonds_train

# %%
# Configurar el tamaño de la figura
plt.figure(figsize=(3, 5))

# Crear un boxplot para la variable "price"
sns.boxplot(y=diamonds_train['carat'])

# Añadir etiquetas y título
plt.xlabel('table')
plt.title('Boxplot de la Variable "carat"')

# Mostrar el gráfico
plt.show()

# %%
# Calcular el rango intercuartílico (IQR)
#Q1 = diamonds_train['carat'].quantile(0.25)
#Q3 = diamonds_train['carat'].quantile(0.75)
#IQR = Q3 - Q1

# Definir límites para identificar outliers
#limite_inferior = Q1 - 1.75 * IQR
#limite_superior = Q3 + 1.75 * IQR

# Filtrar los datos para eliminar outliers
#diamonds_train = diamonds_train[(diamonds_train['carat'] <= limite_superior)]

# Visualizar el DataFrame resultante sin outliers
#diamonds_train

# %%
# Configurar el tamaño de la figura
plt.figure(figsize=(3, 5))

# Crear un boxplot para la variable "price"
sns.boxplot(y=diamonds_train['carat'])

# Añadir etiquetas y título
plt.xlabel('table')
plt.title('Boxplot de la Variable "carat"')

# Mostrar el gráfico
plt.show()

# %%
# Calcular la matriz de correlación
correlation_matrix = diamonds_train_num.corr()

# Configurar el tamaño de la figura
plt.figure(figsize=(8, 6))

# Crear un mapa de calor (heatmap) con seaborn
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)

# Añadir título
plt.title('Matriz de Correlación')

# Mostrar el gráfico
plt.show()

# %%
# x, y, z muy correlacionadas. Habría que eliminar dos variables o hacer una media de las 3.
# carat también muy correlacionada. Se puede eliminar o quizás habría que mantenerla porque está muy correlacionada con price
# Eliminar la variable depth porque apenas tiene correlacion con la variable target y hay muchos outliers (ruido)

# %% [markdown]
# ## Transformación de variables

# %% [markdown]
# ### Eliminación variables

# %%
# Probamos con hacer una media entre x, y, z:
#diamonds_train['mean'] = diamonds_train['x'] * diamonds_train['y'] * diamonds_train['z']
#diamonds_train['mean'] = diamonds_train[['x','y','z']].mean(axis=1)
#diamonds_train['mean']

# %%
#diamonds_train['mean_carat'] = diamonds_train['mean'] * diamonds_train['carat']

# %%
diamonds_train_num = diamonds_train.select_dtypes(include=['number'])
diamonds_train_num
# Out:
#        carat  depth  table     x     y     z  price
# 0       1.21   62.4   58.0  6.83  6.79  4.25   4268
# 1       0.32   63.0   57.0  4.35  4.38  2.75    505
# 2       0.71   65.5   55.0  5.62  5.53  3.65   2686
# 3       0.41   63.8   56.0  4.68  4.72  3.00    738
# 4       1.02   60.5   59.0  6.55  6.51  3.95   4882
# ...      ...    ...    ...   ...   ...   ...    ...
# 40450   1.34   62.7   57.0  7.10  7.04  4.43  10070
# 40451   2.02   57.1   60.0  8.31  8.25  4.73  12615
# 40452   1.01   62.7   56.0  6.37  6.42  4.01   5457
# 40453   0.33   61.9   54.3  4.45  4.47  2.76    456
# 40454   1.24   62.0   58.0  6.83  6.88  4.25   6232
#
# [40439 rows x 7 columns]

# %%
# Calcular la matriz de correlación
correlation_matrix = diamonds_train_num.corr()

# Configurar el tamaño de la figura
plt.figure(figsize=(8, 6))

# Crear un mapa de calor (heatmap) con seaborn
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)

# Añadir título
plt.title('Matriz de Correlación')

# Mostrar el gráfico
plt.show()

# %%
# Eliminación de variables x, y , z y depth
diamonds_train = diamonds_train.drop(columns=['city'])
diamonds_train
# Out:
#        carat        cut color clarity  depth  table     x     y     z  price
# 0       1.21    Premium     J     VS2   62.4   58.0  6.83  6.79  4.25   4268
# 1       0.32  Very Good     H     VS2   63.0   57.0  4.35  4.38  2.75    505
# 2       0.71       Fair     G     VS1   65.5   55.0  5.62  5.53  3.65   2686
# 3       0.41       Good     D     SI1   63.8   56.0  4.68  4.72  3.00    738
# 4       1.02      Ideal     G     SI1   60.5   59.0  6.55  6.51  3.95   4882
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 40450   1.34      Ideal     G     VS1   62.7   57.0  7.10  7.04  4.43  10070
# 40451   2.02       Good     F     SI2   57.1   60.0  8.31  8.25  4.73  12615
# 40452   1.01      Ideal     H     SI1   62.7   56.0  6.37  6.42  4.01   5457
# 40453   0.33      Ideal     J     VS1   61.9   54.3  4.45  4.47  2.76    456
# 40454   1.24      Ideal     I     SI1   62.0   58.0  6.83  6.88  4.25   6232
#
# [40439 rows x 10 columns]

# %%
# Label encoder
def ordinal_encoding(x):
    for key in encoding:
        if x == key:
            return encoding[key]

# %%
# Label Encoding variable clarity
encoding = {'IF': 8, 'VVS1':7, 'VVS2':6, 'VS1':5, 'VS2':4, 'SI1':3, 'SI2':2, 'I1':1}
diamonds_train['clarity'] = diamonds_train['clarity'].apply(ordinal_encoding)
# Label Encoding variable cut
encoding = {'Premium': 4, 'Ideal':5, 'Very Good':3, 'Good':2, 'Fair':1}
diamonds_train['cut'] = diamonds_train['cut'].apply(ordinal_encoding)
# Label Encoding variable cut
encoding = {'D': 7, 'E':6, 'F':5, 'G':4, 'H':3, 'I':2, 'J':1}
diamonds_train['color'] = diamonds_train['color'].apply(ordinal_encoding)

# %%
# Inicializar el LabelEncoder
#label_encoder = LabelEncoder()

# Ajustar y transformar las etiquetas categóricas

#diamonds_train['color'] = label_encoder.fit_transform(diamonds_train['color'])

# %%
# Calcular la matriz de correlación
correlation_matrix = diamonds_train.corr()

# Configurar el tamaño de la figura
plt.figure(figsize=(8, 6))

# Crear un mapa de calor (heatmap) con seaborn
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)

# Añadir título
plt.title('Matriz de Correlación')

# Mostrar el gráfico
plt.show()

# %%
# Nos quedamos con todo menos el target
diamonds_train_x = diamonds_train.drop(columns=['price'])

# %%
diamonds_train_y = diamonds_train['price']
diamonds_train_y
# Out:
# 0         4268
# 1          505
# 2         2686
# 3          738
# 4         4882
#          ...
# 40450    10070
# 40451    12615
# 40452     5457
# 40453      456
# 40454     6232
# Name: price, Length: 40439, dtype: int64

# %% [markdown]
# ### Escalado

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(diamonds_train_x)
diamonds_train_x_scaled = pd.DataFrame(scaled_data)
diamonds_train_x_scaled
# Out:
#               0         1         2         3         4         5         6  \
# 0      0.868119  0.085017 -1.998889 -0.030355  0.452031  0.248298  0.980410
# 1     -1.004574 -0.809596 -0.823417 -0.030355  0.871234 -0.199524 -1.229199
# 2     -0.183956 -2.598821 -0.235682  0.576427  2.617912 -1.095169 -0.097665
# 3     -0.815201 -1.704208  1.527526 -0.637136  1.430171 -0.647347 -0.935178
# 4      0.468330  0.979630 -0.235682 -0.637136 -0.875444  0.696121  0.730938
# ...         ...       ...       ...       ...       ...       ...       ...
# 40434  1.141658  0.979630 -0.235682  0.576427  0.661633 -0.199524  1.220973
# 40435  2.572480 -1.704208  0.352054 -1.243917 -3.250927  1.143943  2.299048
# 40436  0.447289  0.979630 -0.823417 -0.637136  0.661633 -0.647347  0.570564
# 40437 -0.983533  0.979630 -1.998889  0.576427  0.102695 -1.408645 -1.140101
# 40438  0.931243  0.979630 -1.411153 -0.637136  0.172563  0.248298  0.980410
#
#               7         8
# 0      0.923244  1.025686
# 1     -1.181582 -1.136849
# 2     -0.177205  0.160672
# 3     -0.884636 -0.776427
# 4      0.678700  0.593179
# ...         ...       ...
# 40434  1.141587  1.285190
# 40435  2.198366  1.717697
# 40436  0.600096  0.679680
# 40437 -1.102979 -1.122433
# 40438  1.001847  1.025686
#
# [40439 rows x 9 columns]

# %% [markdown]
# ## Modelado

# %% [markdown]
# ### Random Forest

# %%
model_xgb = XGBRegressor(colsample_bytree = 0.95,
                          gamma = 0.14,
                          learning_rate = 0.012,
                          max_depth = 7,
                          missing = np.inf,
                          n_estimators = 1130,
                          subsample = 0.8, 
                         objective='reg:squarederror', random_state=42)

# %%
model = RandomForestRegressor(random_state = 42)

# %%
# %%time


scores = cross_val_score(model, 
                         diamonds_train_x_scaled, 
                         diamonds_train_y, 
                         scoring='neg_root_mean_squared_error', 
                         cv=5,
                         n_jobs=-1)

print(type(model), '\n')
print(scores, '\n')
print(np.mean(-scores), '\n')
# Out:
# <class 'sklearn.ensemble._forest.RandomForestRegressor'>
#
# [-537.39410544 -541.04743736 -544.91259525 -567.88474998 -536.06303773]
#
# 545.4603851535004
#
# CPU times: user 162 ms, sys: 189 ms, total: 351 ms
# Wall time: 50.3 s

# %% [markdown]
# ## Test

# %%
diamonds_test_x = pd.read_csv('./data/diamonds_test.csv')
diamonds_test_x.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  \
# 0   0   0.79  Very Good     F     SI1   62.7   60.0  5.82  5.89  3.67
# 1   1   1.20      Ideal     J     VS1   61.0   57.0  6.81  6.89  4.18
# 2   2   1.57    Premium     H     SI1   62.2   61.0  7.38  7.32  4.57
# 3   3   0.90  Very Good     F     SI1   63.8   54.0  6.09  6.13  3.90
# 4   4   0.50  Very Good     F     VS1   62.9   58.0  5.05  5.09  3.19
#
#         city
# 0  Amsterdam
# 1      Surat
# 2   Kimberly
# 3   Kimberly
# 4  Amsterdam

# %%
diamonds_test_x.describe()
# Out:
#                  id         carat         depth         table             x  \
# count  13485.000000  13485.000000  13485.000000  13485.000000  13485.000000
# mean    6742.000000      0.798642     61.739095     57.490337      5.736454
# std     3892.928525      0.469399      1.435310      2.237109      1.113671
# min        0.000000      0.200000     50.800000     51.000000      0.000000
# 25%     3371.000000      0.400000     61.000000     56.000000      4.730000
# 50%     6742.000000      0.700000     61.900000     57.000000      5.700000
# 75%    10113.000000      1.040000     62.500000     59.000000      6.530000
# max    13484.000000      5.010000     79.000000     73.000000     10.740000
#
#                   y             z
# count  13485.000000  13485.000000
# mean       5.739648      3.543474
# std        1.128507      0.731005
# min        0.000000      0.000000
# 25%        4.730000      2.920000
# 50%        5.720000      3.530000
# 75%        6.530000      4.040000
# max       31.800000     31.800000

# %%
diamonds_test_x.eq(0).sum()
# Out:
# id         1
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          3
# y          3
# z          4
# city       0
# dtype: int64

# %%
# Probamos con hacer una media entre x, y, z:
#diamonds_test_x['mean'] = diamonds_test_x[['x','y','z']].mean(axis=1)
# Eliminacion de columnas id, x, y, z
diamonds_test_x = diamonds_test_x.drop(columns=['id','city'])
# Label Encoding variable clarity
encoding = {'IF': 8, 'VVS1':7, 'VVS2':6, 'VS1':5, 'VS2':4, 'SI1':3, 'SI2':2, 'I1':1}
diamonds_test_x['clarity'] = diamonds_test_x['clarity'].apply(ordinal_encoding)
# Label Encoding variable cut
encoding = {'Premium': 4, 'Ideal':5, 'Very Good':3, 'Good':2, 'Fair':1}
diamonds_test_x['cut'] = diamonds_test_x['cut'].apply(ordinal_encoding)
# Label Encoding variable cut
encoding = {'D': 7, 'E':6, 'F':5, 'G':4, 'H':3, 'I':2, 'J':1}
diamonds_test_x['color'] = diamonds_test_x['color'].apply(ordinal_encoding)
diamonds_test_x
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z
# 0       0.79    3      5        3   62.7   60.0  5.82  5.89  3.67
# 1       1.20    5      1        5   61.0   57.0  6.81  6.89  4.18
# 2       1.57    4      3        3   62.2   61.0  7.38  7.32  4.57
# 3       0.90    3      5        3   63.8   54.0  6.09  6.13  3.90
# 4       0.50    3      5        5   62.9   58.0  5.05  5.09  3.19
# ...      ...  ...    ...      ...    ...    ...   ...   ...   ...
# 13480   0.57    5      6        3   61.9   56.0  5.35  5.32  3.30
# 13481   0.71    5      2        4   62.2   55.0  5.71  5.73  3.56
# 13482   0.70    5      5        5   61.6   55.0  5.75  5.71  3.53
# 13483   0.70    3      5        2   58.8   57.0  5.85  5.89  3.45
# 13484   0.40    5      2        6   62.4   55.0  4.70  4.73  2.94
#
# [13485 rows x 9 columns]

# %%
# Calcular la matriz de correlación
correlation_matrix = diamonds_test_x.corr()

# Configurar el tamaño de la figura
plt.figure(figsize=(8, 6))

# Crear un mapa de calor (heatmap) con seaborn
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)

# Añadir título
plt.title('Matriz de Correlación')

# Mostrar el gráfico
plt.show()

# %%
# Escalado
scaler = StandardScaler()
scaled_data = scaler.fit_transform(diamonds_test_x)
diamonds_test_x_scaled = pd.DataFrame(scaled_data)
diamonds_test_x_scaled
# Out:
#               0         1         2         3         4         5         6  \
# 0     -0.018412 -0.810632  0.340530 -0.642288  0.669500  1.121874  0.075022
# 1      0.855078  0.986700 -2.011650  0.574266 -0.514957 -0.219192  0.964007
# 2      1.643349  0.088034 -0.835560 -0.642288  0.321131  1.568896  1.475847
# 3      0.215939 -0.810632  0.340530 -0.642288  1.435914 -1.560258  0.317472
# 4     -0.636246 -0.810632  0.340530  0.574266  0.808848  0.227830 -0.616411
# ...         ...       ...       ...       ...       ...       ...       ...
# 13480 -0.487114  0.986700  0.928574 -0.642288  0.112109 -0.666214 -0.347022
# 13481 -0.188849  0.986700 -1.423605 -0.034011  0.321131 -1.113236 -0.023755
# 13482 -0.210153  0.986700  0.340530  0.574266 -0.096913 -1.113236  0.012164
# 13483 -0.210153 -0.810632  0.340530 -1.250565 -2.047784 -0.219192  0.101960
# 13484 -0.849292  0.986700 -1.423605  1.182543  0.460479 -1.113236 -0.930699
#
#               7         8
# 0      0.133236  0.173091
# 1      1.019395  0.870787
# 2      1.400444  1.404319
# 3      0.345914  0.487738
# 4     -0.575691 -0.483564
# ...         ...       ...
# 13480 -0.371875 -0.333080
# 13481 -0.008549  0.022608
# 13482 -0.026273 -0.018433
# 13483  0.133236 -0.127876
# 13484 -0.894709 -0.825572
#
# [13485 rows x 9 columns]

# %% [markdown]
# ## Submission

# %%
model.fit(diamonds_train_x_scaled, diamonds_train_y)
y_pred = model.predict(diamonds_test_x_scaled)
y_pred
# Out:
# array([3053.2 , 5372.23, 9704.79, ..., 2866.86, 2175.51,  825.05])

# %%
len(y_pred)
# Out:
# 13485

# %%
y_pred_df = pd.DataFrame(y_pred)
y_pred_df.reset_index(inplace=True)
y_pred_df.columns = ['id', 'price']
y_pred_df.to_csv('./data/submisions1.csv', index=False)

# %% [markdown]
# ## Grid Search

# %%
# Random Forest Regressor

param_grid = {'n_estimators': [100, 200, 300],  # Number of trees in the forest.
              'max_depth': [None, 3, 10],  # Maximum depth of the trees.
              'min_samples_split': [2, 10],  # Minimum number of samples required to split an internal node.
              'min_samples_leaf': [1, 4],  # Minimum number of samples required to be at a leaf node.
              'max_features': [None, 'sqrt', 'log2']  # Number of features to consider when looking for the best split.
              }

# %%
grid_search = GridSearchCV(model,
                           param_grid,
                           cv=5,
                           verbose=3,
                           scoring='neg_root_mean_squared_error',
                           n_jobs=-1)

# %%
# %%time

grid_search.fit(diamonds_train_x_scaled,diamonds_train_y)

print('\n')
print('Best hyperparameters: ', grid_search.best_params_, '\n')
print('Best score: ', -grid_search.best_score_, '\n')
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
#
#
# Best hyperparameters:  {'max_depth': None, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 300}
#
# Best score:  544.4170783126589
#
# CPU times: user 49.8 s, sys: 3.47 s, total: 53.3 s
# Wall time: 52min 26s

# %%
y_pred = model.predict(diamonds_test_x_scaled)

# %%
# Random Forest Regressor

param_grid = {'n_estimators': [500,700, 900],  # Number of trees in the forest.
              'max_depth': [None],  # Maximum depth of the trees.
              'min_samples_split': [5, 6, 8],  # Minimum number of samples required to split an internal node.
              'min_samples_leaf': [1],  # Minimum number of samples required to be at a leaf node.
              'max_features': [None]  # Number of features to consider when looking for the best split.
             }

# %%
# %%time

grid_search.fit(diamonds_train_x_scaled,diamonds_train_y)

print('\n')
print('Best hyperparameters: ', grid_search.best_params_, '\n')
print('Best score: ', -grid_search.best_score_, '\n')
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:1
#
# File ~/miniconda3/envs/m3_env/lib/python3.8/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~/miniconda3/envs/m3_env/lib/python3.8/site-packages/sklearn/model_selection/_search.py:898, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     892     results = self._format_results(
#     893         all_candidate_params, n_splits, all_out, all_more_results
#     894     )
#     896     return results
# --> 898 self._run_search(evaluate_candidates)
#     900 # multimetric is determined here because in the case of a callable
#     901 # self.scoring the return type is only known after calling
#     902 first_test_score = all_out[0]["test_scores"]
#
# File ~/miniconda3/envs/m3_env/lib/python3.8/site-packages/sklearn/model_selection/_search.py:1422, in GridSearchCV._run_search(self, evaluate_candidates)
#    1420 def _run_search(self, evaluate_candidates):
#    1421     """Search all candidates in param_grid"""
# -> 1422     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/miniconda3/envs/m3_env/lib/python3.8/site-packages/sklearn/model_selection/_search.py:845, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     837 if self.verbose > 0:
#     838     print(
#     839         "Fitting {0} folds for each of {1} candidates,"
#     840         " totalling {2} fits".format(
#     841             n_splits, n_candidates, n_candidates * n_splits
#     842         )
#     843     )
# --> 845 out = parallel(
#     846     delayed(_fit_and_score)(
#     847         clone(base_estimator),
#     848         X,
#     849         y,
#     850         train=train,
#     851         test=test,
#     852         parameters=parameters,
#     853         split_progress=(split_idx, n_splits),
#     854         candidate_progress=(cand_idx, n_candidates),
#     855         **fit_and_score_kwargs,
#     856     )
#     857     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     858         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     859     )
#     860 )
#     862 if len(out) < 1:
#     863     raise ValueError(
#     864         "No fits were performed. "
#     865         "Was the CV iterator empty? "
#     866         "Were there no candidates?"
#     867     )
#
# File ~/miniconda3/envs/m3_env/lib/python3.8/site-packages/sklearn/utils/parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File ~/miniconda3/envs/m3_env/lib/python3.8/site-packages/joblib/parallel.py:1952, in Parallel.__call__(self, iterable)
#    1946 # The first item from the output is blank, but it makes the interpreter
#    1947 # progress until it enters the Try/Except block of the generator and
#    1948 # reach the first `yield` statement. This starts the aynchronous
#    1949 # dispatch of the tasks to the workers.
#    1950 next(output)
# -> 1952 return output if self.return_generator else list(output)
#
# File ~/miniconda3/envs/m3_env/lib/python3.8/site-packages/joblib/parallel.py:1595, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1592     yield
#    1594     with self._backend.retrieval_context():
# -> 1595         yield from self._retrieve()
#    1597 except GeneratorExit:
#    1598     # The generator has been garbage collected before being fully
#    1599     # consumed. This aborts the remaining tasks if possible and warn
#    1600     # the user if necessary.
#    1601     self._exception = True
#
# File ~/miniconda3/envs/m3_env/lib/python3.8/site-packages/joblib/parallel.py:1707, in Parallel._retrieve(self)
#    1702 # If the next job is not ready for retrieval yet, we just wait for
#    1703 # async callbacks to progress.
#    1704 if ((len(self._jobs) == 0) or
#    1705     (self._jobs[0].get_status(
#    1706         timeout=self.timeout) == TASK_PENDING)):
# -> 1707     time.sleep(0.01)
#    1708     continue
#    1710 # We need to be careful: the job list can be filling up as
#    1711 # we empty it and Python list are not thread-safe by
#    1712 # default hence the use of the lock
#
# KeyboardInterrupt:
